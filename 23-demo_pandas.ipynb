# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#             Name                      Email
# 0    Alice Smith    alice.smith@example.com
# 1    Bob Johnson    bob.johnson@example.com
# 2  Charlie Brown  charlie.brown@example.com
# 3   Diana Miller   diana.miller@example.com
# 4   Edward Davis   edward.davis@example.com

# %%
df.tail()
# Out:
#                Name                         Email
# 5      Fiona Garcia      fiona.garcia@example.com
# 6  George Rodriguez  george.rodriguez@example.com
# 7     Hannah Wilson     hannah.wilson@example.com
# 8    Isaac Martinez    isaac.martinez@example.com
# 9    Julia Anderson    julia.anderson@example.com

# %%
house_df = pd.read_csv('house_rent.csv')

# %%
house_df.head()
# Out:
#     Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100.0  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800.0       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000.0       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800.0       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# ...

# %%
house_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4744.000000  4746.000000
# mean      2.083860  3.499345e+04   967.766863     1.965866
# std       0.832256  7.810641e+04   634.192059     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
print(f"House Rents: {house_df['Rent'].count():.2f}")
# Out:
# House Rents: 4746.00

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4744 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 445.1+ KB

# %%
house_df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 2
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
data_dict={
    "city": ["Bangalore", "Kolkata","Delhi","Chennai","Mumbai"],
    "population": [45,67,None,82,96]
}

# %%
data_df = pd.DataFrame(data_dict)
data_df.head()
# Out:
#         city  population
# 0  Bangalore        45.0
# 1    Kolkata        67.0
# 2      Delhi         NaN
# 3    Chennai        82.0
# 4     Mumbai        96.0

# %%
data_df.isna().sum()
# Out:
# city          0
# population    1
# dtype: int64

# %%
data_df1 = data_df.dropna()
data_df1.head()
# Out:
#         city  population
# 0  Bangalore        45.0
# 1    Kolkata        67.0
# 3    Chennai        82.0
# 4     Mumbai        96.0

# %%
data_df2 = data_df['population'].fillna(0)
data_df2.head()
# Out:
# 0    45.0
# 1    67.0
# 2     0.0
# 3    82.0
# 4    96.0
# Name: population, dtype: float64

# %%
# Adding back the 'city' column to the filled DataFrame 
data_df2 = pd.DataFrame({
    'city': data_df['city'],
    'population': data_df['population'].fillna(0)
})
data_df2.head()
# Out:
#         city  population
# 0  Bangalore        45.0
# 1    Kolkata        67.0
# 2      Delhi         0.0
# 3    Chennai        82.0
# 4     Mumbai        96.0

# %%
df.to_sql('data_table', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_sql('data_table', con=engine, if_exists='replace', index=False)
#
# NameError: name 'engine' is not defined

# %%
plt.plot(house_df['Size'], house_df['Rent'], 'o')
plt.xlabel('Size (sq ft)')
plt.ylabel('Rent')
plt.title('House Size vs Rent')
plt.show()

# %%
data_df2.plot(kind='bar', x='city', y='population', title='City Populations')
plt.xlabel('City')
plt.ylabel('Population (in lakhs)')
plt.show()
