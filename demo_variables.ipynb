# %%
x = 10

# %% [markdown]
# - Dynamically typed language
# - Weakly typed language

# %% [markdown]
# ## Rules for naming
# - variable names cannot be a `keyword`
# - It can contain `alpha_numeric` & `underscores`
# - It cannot start with a number

# %% [markdown]
# ## Conventions of naming
# - give meaningful names
# - we follow `snake_case`

# %%
number_of_words = 100
print(number_of_words)
print(type(number_of_words))
# Out:
# 100
# <class 'int'>

# %% [markdown]
# ## Data Types in Python

# %%
number_of_words = 100
print(number_of_words)
print(type(number_of_words))
# Out:
# 100
# <class 'int'>

# %%
amount = 100980230918209182402834.23
print(amount)
print(type(amount))
# Out:
# 1.0098023091820919e+23
# <class 'float'>

# %%
number_of_words = 1009803265016325091326501982346109832570324896502943865094326094328750219837487329879879812312382749898797097097080980809767645653254
print(number_of_words)
print(type(number_of_words))
# Out:
# 1009803265016325091326501982346109832570324896502943865094326094328750219837487329879879812312382749898797097097080980809767645653254
# <class 'int'>

# %%
number_of_words = 19e3
print(number_of_words)
print(type(number_of_words))
# Out:
# 19000.0
# <class 'float'>

# %%
bin_num = 0b101
print(bin_num)
print(type(bin_num))
# Out:
# 5
# <class 'int'>

# %%
hex_num = 0xAb
print(hex_num)
print(type(hex_num))
# Out:
# 171
# <class 'int'>

# %%
oct_num = 0o3
print(oct_num)
print(type(oct_num))
# Out:
# 3
# <class 'int'>

# %%
boolean_value = True
print(boolean_value)
print(type(boolean_value))
# Out:
# True
# <class 'bool'>

# %%
user_name = 'Vishwas'
print(user_name)
print(type(user_name))
# Out:
# Vishwas
# <class 'str'>

# %%
sentence = "This is Vishwas's dairy"
print(sentence)
print(type(sentence))
# Out:
# This is Vishwas's dairy
# <class 'str'>

# %%
sentence = 'This is Vishwas\'s dairy'
print(sentence)
print(type(sentence))
# Out:
# This is Vishwas's dairy
# <class 'str'>

# %%
sentence = 'This is Vishwas"s dairy'
print(sentence)
print(type(sentence))
# Out:
# This is Vishwas"s dairy
# <class 'str'>

# %%
sentence = '''This is Vishwas's dairy.
Vishwas is teaching python.
We are from EY'''
print(sentence)
print(type(sentence))
# Out:
# This is Vishwas's dairy.
# Vishwas is teaching python.
# We are from EY
# <class 'str'>
